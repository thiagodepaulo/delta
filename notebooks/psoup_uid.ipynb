# %%
import pandas as pd

# %%
df_train = pd.read_parquet('../data/psoup/psoup_train_with_emb.parquet')
df_test = pd.read_parquet('../data/psoup/psoup_test_with_emb.parquet')

# %%
df_train['u_id'] = df_train['uid'] -1
df_test['u_id'] = df_test['uid'] -1

# %%
df_train.to_parquet('../data/psoup/psoup_train_with_emb_uid.parquet')
df_test.to_parquet('../data/psoup/psoup_test_with_emb_uid.parquet')
